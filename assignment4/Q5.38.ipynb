# %% [markdown]
# Q 5.38

# %%
library(Stat2Data)
data(Meniscus)
str(Meniscus)
# Out:
# 'data.frame':	18 obs. of  4 variables:
#  $ Method      : int  1 1 1 1 1 1 2 2 2 2 ...
#  $ FailureLoad : num  97.3 106.4 118.2 99.7 106.5 ...
#  $ Displacement: num  16.9 20.2 20.1 15.7 13.9 14.9 7.9 12.5 15.5 10.2 ...
#  $ Stiffness   : num  8.3 7.2 6.3 7.3 8.7 8.7 4.7 6.1 5 5.8 ...

# %% [markdown]
# part a \
# H0: alpah1 = alpha2 = alpha3 = 0 \
# Ha: at least one of alpha-i not 0 \
# alpha1 is the group effect for vertical sututre \

# %%
# part b
linearmodel = lm(Stiffness ~ factor(Method),data = Meniscus)
plot(linearmodel)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
filter_method0 = Meniscus %>% filter(Method == 1)
filter_method0$Stiffness
sd(filter_method0$Stiffness)
# Out:
# [1] 8.3 7.2 6.3 7.3 8.7 8.7
# [1] 0.9710819

# %%
filter_method1 = Meniscus %>% filter(Method == 2)
filter_method1
# Out:
#   Method FailureLoad Displacement Stiffness
# 1 2      44.9         7.9         4.7
# 2 2      46.1        12.5         6.1
# 3 2      59.3        15.5         5.0
# 4 2      35.5        10.2         5.8
# 5 2      50.7         8.9         6.6
# 6 2      56.8        13.3         8.4

# %%
filter_method2 = Meniscus %>% filter(Method == 3)
filter_method2
# Out:
#   Method FailureLoad Displacement Stiffness
# 1 3       88.0       18.0         8.0
# 2 3      119.8       18.5         8.3
# 3 3       65.8        9.2         7.6
# 4 3       82.9       18.8         6.4
# 5 3      149.9       22.8         8.2
# 6 3      117.1       17.5         7.7

# %%
sd(filter_method0$Stiffness)
sd(filter_method1$Stiffness)
sd(filter_method2$Stiffness)
# Out:
# [1] 0.9710819
# [1] 1.32665
# [1] 0.6928203

# %%
1.33 / 0.693
# Out:
# [1] 1.919192

# %% [markdown]
# Constant variance is OK, but Normality has a little problem with random samples, so we can perform an ANOVA.

# %%
# part c
linearmodel1 = aov(Stiffness~factor(Method), data=Meniscus)
summary(linearmodel1)
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# factor(Method)  2  10.57   5.285   4.981 0.0219 *
# Residuals      15  15.91   1.061
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# We have evidence that at least one treatment can affectmean amount of stiffness.
