# %% [markdown]
# Q 5.40

# %% [markdown]
# part a. \
# H0: alpah1 = alpha2 = alpha3 = 0 \
# Ha: at least one of alpha-i not 0

# %%
library(Stat2Data)
data(Meniscus)
str(Meniscus)
# Out:
# 'data.frame':	18 obs. of  4 variables:
#  $ Method      : int  1 1 1 1 1 1 2 2 2 2 ...
#  $ FailureLoad : num  97.3 106.4 118.2 99.7 106.5 ...
#  $ Displacement: num  16.9 20.2 20.1 15.7 13.9 14.9 7.9 12.5 15.5 10.2 ...
#  $ Stiffness   : num  8.3 7.2 6.3 7.3 8.7 8.7 4.7 6.1 5 5.8 ...

# %%
linearmodel2 = lm(Displacement ~ factor(Method), data = Meniscus)
plot(linearmodel2)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
filter_method0 = Meniscus %>% filter(Method == 1)
filter_method0
filter_method0$Displacement
# Out:
#   Method FailureLoad Displacement Stiffness
# 1 1       97.3       16.9         8.3
# 2 1      106.4       20.2         7.2
# 3 1      118.2       20.1         6.3
# 4 1       99.7       15.7         7.3
# 5 1      106.5       13.9         8.7
# 6 1       84.2       14.9         8.7
# [1] 16.9 20.2 20.1 15.7 13.9 14.9

# %%
filter_method1 = Meniscus %>% filter(Method == 2)
filter_method1
filter_method1$Displacement
# Out:
#   Method FailureLoad Displacement Stiffness
# 1 2      44.9         7.9         4.7
# 2 2      46.1        12.5         6.1
# 3 2      59.3        15.5         5.0
# 4 2      35.5        10.2         5.8
# 5 2      50.7         8.9         6.6
# 6 2      56.8        13.3         8.4
# [1]  7.9 12.5 15.5 10.2  8.9 13.3

# %%
filter_method2 = Meniscus %>% filter(Method == 3)
filter_method2
filter_method2$Displacement
# Out:
#   Method FailureLoad Displacement Stiffness
# 1 3       88.0       18.0         8.0
# 2 3      119.8       18.5         8.3
# 3 3       65.8        9.2         7.6
# 4 3       82.9       18.8         6.4
# 5 3      149.9       22.8         8.2
# 6 3      117.1       17.5         7.7
# [1] 18.0 18.5  9.2 18.8 22.8 17.5

# %%
sd(filter_method0$Displacement)
sd(filter_method1$Displacement)
sd(filter_method2$Displacement)
# Out:
# [1] 2.666646
# [1] 2.883343
# [1] 4.470198

# %%
4.47 / 2.67
# Out:
# [1] 1.674157

# %% [markdown]
# Constant variance and normality both satisfied.

# %%
aovmodel = aov(Displacement ~ factor(Method), data = Meniscus)
summary(aovmodel)
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# factor(Method)  2  136.5   68.26   5.784 0.0137 *
# Residuals      15  177.0   11.80
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# pvalue = 0.0137, very small, REJECT H0, we have evidence that AT LEAST ONE TREATMENT CAN AFFECT MEAN DISPLACEMENT.

# %%
print(Meniscus)
# Out:
#    Method FailureLoad Displacement Stiffness
# 1       1        97.3         16.9       8.3
# 2       1       106.4         20.2       7.2
# 3       1       118.2         20.1       6.3
# 4       1        99.7         15.7       7.3
# 5       1       106.5         13.9       8.7
# 6       1        84.2         14.9       8.7
# 7       2        44.9          7.9       4.7
# 8       2        46.1         12.5       6.1
# 9       2        59.3         15.5       5.0
# 10      2        35.5         10.2       5.8
# 11      2        50.7          8.9       6.6
# 12      2        56.8         13.3       8.4
# 13      3        88.0         18.0       8.0
# 14      3       119.8         18.5       8.3
# 15      3        65.8          9.2       7.6
# 16      3        82.9         18.8       6.4
# 17      3       149.9         22.8       8.2
# 18      3       117.1         17.5       7.7
